# %%
library(RSQMC) # for internal filters
library(ggplot2)

# %%
unif = data.frame(matrix(runif(500, 0, 1), c(250, 2)))
ggplot(unif, aes(x=X1, y=X2)) + geom_point(color="blue")
# Out:
# plot without title

# %%
sobol = data.frame(t(gen_sobol(2, 250)))
ggplot(sobol, aes(x=X1, y=X2)) + geom_point(color="blue")
# Out:
# plot without title
